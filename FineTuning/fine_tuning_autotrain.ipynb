# %%
# !pip install -U autotrain-advanced
# Out:
# Collecting autotrain-advanced
#   Downloading autotrain_advanced-0.8.36-py3-none-any.whl.metadata (21 kB)
# Collecting albumentations==1.4.23 (from autotrain-advanced)
#   Downloading albumentations-1.4.23-py3-none-any.whl.metadata (36 kB)
# Collecting datasets~=3.2.0 (from datasets[vision]~=3.2.0->autotrain-advanced)
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Collecting evaluate==0.4.3 (from autotrain-advanced)
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting ipadic==1.0.0 (from autotrain-advanced)
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 151.6 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting jiwer==3.0.5 (from autotrain-advanced)
#   Downloading jiwer-3.0.5-py3-none-any.whl.metadata (2.7 kB)
# Collecting joblib==1.4.2 (from autotrain-advanced)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting loguru==0.7.3 (from autotrain-advanced)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting pandas==2.2.3 (from autotrain-advanced)
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: nltk==3.9.1 in /usr/local/lib/python3.12/dist-packages (from autotrain-advanced) (3.9.1)
# Collecting optuna==4.1.0 (from autotrain-advanced)
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting Pillow==11.0.0 (from autotrain-advanced)
#   Downloading pillow-11.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting sacremoses==0.1.1 (from autotrain-advanced)
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting scikit-learn==1.6.0 (from autotrain-advanced)
#   Downloading scikit_learn-1.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting sentencepiece==0.2.0 (from autotrain-advanced)
#   Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.12/dist-packages (from autotrain-advanced) (4.67.1)
# Collecting werkzeug==3.1.3 (from autotrain-advanced)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting xgboost==2.1.3 (from autotrain-advanced)
#   Downloading xgboost-2.1.3-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub==0.27.0 (from autotrain-advanced)
#   Downloading huggingface_hub-0.27.0-py3-none-any.whl.metadata (13 kB)
# Collecting requests==2.32.3 (from autotrain-advanced)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting einops==0.8.0 (from autotrain-advanced)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting packaging==24.2 (from autotrain-advanced)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting cryptography==44.0.0 (from autotrain-advanced)
#   Downloading cryptography-44.0.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.7 kB)
# Collecting nvitop==1.3.2 (from autotrain-advanced)
#   Downloading nvitop-1.3.2-py3-none-any.whl.metadata (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 8.2 MB/s eta 0:00:00
# Collecting tensorboard==2.18.0 (from autotrain-advanced)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting peft==0.14.0 (from autotrain-advanced)
#   Downloading peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# Collecting trl==0.13.0 (from autotrain-advanced)
#   Downloading trl-0.13.0-py3-none-any.whl.metadata (11 kB)
# Collecting tiktoken==0.8.0 (from autotrain-advanced)
#   Downloading tiktoken-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting transformers==4.48.0 (from autotrain-advanced)
#   Downloading transformers-4.48.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.7 MB/s eta 0:00:00
# Collecting accelerate==1.2.1 (from autotrain-advanced)
#   Downloading accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Collecting rouge-score==0.1.2 (from autotrain-advanced)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting py7zr==0.22.0 (from autotrain-advanced)
#   Downloading py7zr-0.22.0-py3-none-any.whl.metadata (16 kB)
# Collecting fastapi==0.115.6 (from autotrain-advanced)
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn==0.34.0 (from autotrain-advanced)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting python-multipart==0.0.20 (from autotrain-advanced)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting pydantic==2.10.4 (from autotrain-advanced)
#   Downloading pydantic-2.10.4-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: hf-transfer in /usr/local/lib/python3.12/dist-packages (from autotrain-advanced) (0.1.9)
# Collecting pyngrok==7.2.1 (from autotrain-advanced)
#   Downloading pyngrok-7.2.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting authlib==1.4.0 (from autotrain-advanced)
#   Downloading Authlib-1.4.0-py2.py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: itsdangerous==2.2.0 in /usr/local/lib/python3.12/dist-packages (from autotrain-advanced) (2.2.0)
# Collecting seqeval==1.2.2 (from autotrain-advanced)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: httpx==0.28.1 in /usr/local/lib/python3.12/dist-packages (from autotrain-advanced) (0.28.1)
# Collecting pyyaml==6.0.2 (from autotrain-advanced)
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting timm==1.0.12 (from autotrain-advanced)
#   Downloading timm-1.0.12-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.6/51.6 kB 5.2 MB/s eta 0:00:00
# Collecting torchmetrics==1.6.0 (from autotrain-advanced)
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Collecting pycocotools==2.0.8 (from autotrain-advanced)
#   Downloading pycocotools-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting sentence-transformers==3.3.1 (from autotrain-advanced)
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Collecting bitsandbytes==0.45.0 (from autotrain-advanced)
#   Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.2.1->autotrain-advanced) (2.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==1.2.1->autotrain-advanced) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.2.1->autotrain-advanced) (2.9.0+cu126)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.2.1->autotrain-advanced) (0.7.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.23->autotrain-advanced) (1.16.3)
# Collecting albucore==0.0.21 (from albumentations==1.4.23->autotrain-advanced)
#   Downloading albucore-0.0.21-py3-none-any.whl.metadata (5.3 kB)
# Collecting eval-type-backport (from albumentations==1.4.23->autotrain-advanced)
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.23->autotrain-advanced) (4.12.0.88)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes==0.45.0->autotrain-advanced) (4.15.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography==44.0.0->autotrain-advanced) (2.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.3->autotrain-advanced) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.3->autotrain-advanced) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.3->autotrain-advanced) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate==0.4.3->autotrain-advanced) (2025.3.0)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi==0.115.6->autotrain-advanced)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->autotrain-advanced) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->autotrain-advanced) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->autotrain-advanced) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->autotrain-advanced) (3.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.27.0->autotrain-advanced) (3.20.2)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from jiwer==3.0.5->autotrain-advanced) (8.3.1)
# Collecting rapidfuzz<4,>=3 (from jiwer==3.0.5->autotrain-advanced)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1->autotrain-advanced) (2025.11.3)
# Collecting nvidia-ml-py<12.536.0a0,>=11.450.51 (from nvitop==1.3.2->autotrain-advanced)
#   Downloading nvidia_ml_py-12.535.161-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: cachetools>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from nvitop==1.3.2->autotrain-advanced) (6.2.4)
# Requirement already satisfied: termcolor>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from nvitop==1.3.2->autotrain-advanced) (3.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna==4.1.0->autotrain-advanced) (1.17.2)
# Collecting colorlog (from optuna==4.1.0->autotrain-advanced)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna==4.1.0->autotrain-advanced) (2.0.45)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.3->autotrain-advanced) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.3->autotrain-advanced) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.3->autotrain-advanced) (2025.3)
# Collecting texttable (from py7zr==0.22.0->autotrain-advanced)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from py7zr==0.22.0->autotrain-advanced) (3.23.0)
# Collecting pyzstd>=0.15.9 (from py7zr==0.22.0->autotrain-advanced)
#   Downloading pyzstd-0.19.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr==0.22.0->autotrain-advanced)
#   Downloading pyppmd-1.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr==0.22.0->autotrain-advanced)
#   Downloading pybcj-1.0.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.9 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr==0.22.0->autotrain-advanced)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr==0.22.0->autotrain-advanced)
#   Downloading inflate64-1.0.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from py7zr==0.22.0->autotrain-advanced) (1.2.0)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pycocotools==2.0.8->autotrain-advanced) (3.10.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic==2.10.4->autotrain-advanced) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic==2.10.4->autotrain-advanced)
#   Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->autotrain-advanced) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->autotrain-advanced) (2.5.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score==0.1.2->autotrain-advanced) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score==0.1.2->autotrain-advanced) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.6.0->autotrain-advanced) (3.6.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.18.0->autotrain-advanced) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.18.0->autotrain-advanced) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.18.0->autotrain-advanced) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.18.0->autotrain-advanced) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.18.0->autotrain-advanced) (0.7.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm==1.0.12->autotrain-advanced) (0.24.0+cu126)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics==1.6.0->autotrain-advanced)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers==4.48.0->autotrain-advanced)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from trl==0.13.0->autotrain-advanced) (13.9.4)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn==0.34.0->autotrain-advanced) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug==3.1.3->autotrain-advanced) (3.0.3)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==2.1.3->autotrain-advanced) (2.27.5)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.21->albumentations==1.4.23->autotrain-advanced) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.21->albumentations==1.4.23->autotrain-advanced) (6.5.12)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets~=3.2.0->datasets[vision]~=3.2.0->autotrain-advanced) (18.1.0)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate==0.4.3->autotrain-advanced)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets~=3.2.0->datasets[vision]~=3.2.0->autotrain-advanced) (3.13.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna==4.1.0->autotrain-advanced) (1.3.10)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography==44.0.0->autotrain-advanced) (2.23)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets~=3.2.0->datasets[vision]~=3.2.0->autotrain-advanced) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets~=3.2.0->datasets[vision]~=3.2.0->autotrain-advanced) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets~=3.2.0->datasets[vision]~=3.2.0->autotrain-advanced) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets~=3.2.0->datasets[vision]~=3.2.0->autotrain-advanced) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets~=3.2.0->datasets[vision]~=3.2.0->autotrain-advanced) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets~=3.2.0->datasets[vision]~=3.2.0->autotrain-advanced) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets~=3.2.0->datasets[vision]~=3.2.0->autotrain-advanced) (1.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.8->autotrain-advanced) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.8->autotrain-advanced) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.8->autotrain-advanced) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.8->autotrain-advanced) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0.8->autotrain-advanced) (3.3.1)
# Collecting backports-zstd>=1.0.0 (from pyzstd>=0.15.9->py7zr==0.22.0->autotrain-advanced)
#   Downloading backports_zstd-1.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna==4.1.0->autotrain-advanced) (3.3.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (0.7.1)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (3.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->trl==0.13.0->autotrain-advanced) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->trl==0.13.0->autotrain-advanced) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->trl==0.13.0->autotrain-advanced) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.0->accelerate==1.2.1->autotrain-advanced) (1.3.0)
# Downloading autotrain_advanced-0.8.36-py3-none-any.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.3/341.3 kB 30.8 MB/s eta 0:00:00
# Downloading accelerate-1.2.1-py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.4/336.4 kB 33.2 MB/s eta 0:00:00
# Downloading albumentations-1.4.23-py3-none-any.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.9/269.9 kB 27.1 MB/s eta 0:00:00
# Downloading Authlib-1.4.0-py2.py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.5/225.5 kB 23.5 MB/s eta 0:00:00
# Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 14.3 MB/s eta 0:00:0000:01:00:01
# Downloading cryptography-44.0.0-cp39-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 130.1 MB/s eta 0:00:00
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 4.2 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 9.3 MB/s eta 0:00:00
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 10.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.27.0-py3-none-any.whl (450 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.5/450.5 kB 36.9 MB/s eta 0:00:00
# Downloading jiwer-3.0.5-py3-none-any.whl (21 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 23.7 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.0 MB/s eta 0:00:00
# Downloading nvitop-1.3.2-py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.4/215.4 kB 20.0 MB/s eta 0:00:00
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 28.4 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.1 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 112.3 MB/s eta 0:00:0000:010:01
# Downloading peft-0.14.0-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 33.8 MB/s eta 0:00:00
# Downloading pillow-11.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 93.0 MB/s eta 0:00:00:00:01
# Downloading py7zr-0.22.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 7.0 MB/s eta 0:00:00
# Downloading pycocotools-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.5/443.5 kB 41.2 MB/s eta 0:00:00
# Downloading pydantic-2.10.4-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.8/431.8 kB 41.1 MB/s eta 0:00:00
# Downloading pyngrok-7.2.1-py3-none-any.whl (22 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 50.9 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.2 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 64.2 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 101.1 MB/s eta 0:00:0000:0100:01
# Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.4 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.8 MB/s eta 0:00:00
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 104.3 MB/s eta 0:00:0000:01
# Downloading tiktoken-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 73.2 MB/s eta 0:00:00
# Downloading timm-1.0.12-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 89.8 MB/s eta 0:00:00
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 66.5 MB/s eta 0:00:00
# Downloading transformers-4.48.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 118.1 MB/s eta 0:00:0000:0100:01
# Downloading trl-0.13.0-py3-none-any.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.4/293.4 kB 30.2 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 7.2 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 24.0 MB/s eta 0:00:00
# Downloading xgboost-2.1.3-py3-none-manylinux_2_28_x86_64.whl (153.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 MB 6.7 MB/s eta 0:00:00:00:0100:01
# Downloading albucore-0.0.21-py3-none-any.whl (12 kB)
# Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 111.6 MB/s eta 0:00:00
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 45.2 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 21.2 MB/s eta 0:00:00
# Downloading inflate64-1.0.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 11.7 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading nvidia_ml_py-12.535.161-py3-none-any.whl (37 kB)
# Downloading pybcj-1.0.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 5.3 MB/s eta 0:00:00
# Downloading pyppmd-1.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.8/142.8 kB 13.1 MB/s eta 0:00:00
# Downloading pyzstd-0.19.1-py3-none-any.whl (23 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 125.7 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 8.8 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 121.2 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading backports_zstd-1.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.2/494.2 kB 49.7 MB/s eta 0:00:00
# Building wheels for collected packages: ipadic, rouge-score, seqeval
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556704 sha256=d33fc85a48d24657f21d097443d2e58e3d70ac448db96f33477719099c38e962
#   Stored in directory: /root/.cache/pip/wheels/93/8b/55/dd5978a069678c372520847cf84ba2ec539cb41917c00a2206
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=567c92f2f09e2d07104c91a184baa7df99774de7db344cbd4126e84c13dee44a
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=ef4074ed994309063d11e2797a00cde56c8625a41d9a48a4039981e3848dfa80
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built ipadic rouge-score seqeval
# Installing collected packages: texttable, sentencepiece, nvidia-ml-py, ipadic, werkzeug, uvicorn, requests, rapidfuzz, pyyaml, python-multipart, pyppmd, pydantic-core, pybcj, Pillow, packaging, nvitop, multivolumefile, loguru, joblib, inflate64, fsspec, eval-type-backport, einops, colorlog, backports-zstd, xgboost, tiktoken, tensorboard, starlette, scikit-learn, sacremoses, pyzstd, pyngrok, pydantic, pandas, lightning-utilities, jiwer, huggingface-hub, cryptography, albucore, tokenizers, seqeval, rouge-score, pycocotools, py7zr, optuna, fastapi, authlib, albumentations, transformers, torchmetrics, datasets, bitsandbytes, accelerate, trl, timm, sentence-transformers, peft, evaluate, autotrain-advanced
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.1
#     Uninstalling sentencepiece-0.2.1:
#       Successfully uninstalled sentencepiece-0.2.1
#   Attempting uninstall: nvidia-ml-py
#     Found existing installation: nvidia-ml-py 13.590.44
#     Uninstalling nvidia-ml-py-13.590.44:
#       Successfully uninstalled nvidia-ml-py-13.590.44
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.1.5
#     Uninstalling Werkzeug-3.1.5:
#       Successfully uninstalled Werkzeug-3.1.5
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.40.0
#     Uninstalling uvicorn-0.40.0:
#       Successfully uninstalled uvicorn-0.40.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.3
#     Uninstalling PyYAML-6.0.3:
#       Successfully uninstalled PyYAML-6.0.3
#   Attempting uninstall: python-multipart
#     Found existing installation: python-multipart 0.0.21
#     Uninstalling python-multipart-0.0.21:
#       Successfully uninstalled python-multipart-0.0.21
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.4
#     Uninstalling pydantic_core-2.41.4:
#       Successfully uninstalled pydantic_core-2.41.4
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.3
#     Uninstalling joblib-1.5.3:
#       Successfully uninstalled joblib-1.5.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.1
#     Uninstalling einops-0.8.1:
#       Successfully uninstalled einops-0.8.1
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.1.2
#     Uninstalling xgboost-3.1.2:
#       Successfully uninstalled xgboost-3.1.2
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.12.0
#     Uninstalling tiktoken-0.12.0:
#       Successfully uninstalled tiktoken-0.12.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.19.0
#     Uninstalling tensorboard-2.19.0:
#       Successfully uninstalled tensorboard-2.19.0
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.50.0
#     Uninstalling starlette-0.50.0:
#       Successfully uninstalled starlette-0.50.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.3
#     Uninstalling pydantic-2.12.3:
#       Successfully uninstalled pydantic-2.12.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.24
#     Uninstalling albucore-0.0.24:
#       Successfully uninstalled albucore-0.0.24
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.11
#     Uninstalling pycocotools-2.0.11:
#       Successfully uninstalled pycocotools-2.0.11
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.123.10
#     Uninstalling fastapi-0.123.10:
#       Successfully uninstalled fastapi-0.123.10
#   Attempting uninstall: authlib
#     Found existing installation: Authlib 1.6.6
#     Uninstalling Authlib-1.6.6:
#       Successfully uninstalled Authlib-1.6.6
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 2.0.8
#     Uninstalling albumentations-2.0.8:
#       Successfully uninstalled albumentations-2.0.8
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.3
#     Uninstalling transformers-4.57.3:
#       Successfully uninstalled transformers-4.57.3
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.12.0
#     Uninstalling accelerate-1.12.0:
#       Successfully uninstalled accelerate-1.12.0
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.24
#     Uninstalling timm-1.0.24:
#       Successfully uninstalled timm-1.0.24
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 5.2.0
#     Uninstalling sentence-transformers-5.2.0:
#       Successfully uninstalled sentence-transformers-5.2.0
#   Attempting uninstall: peft
#     Found existing installation: peft 0.18.0
#     Uninstalling peft-0.18.0:
#       Successfully uninstalled peft-0.18.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# pyopenssl 24.2.1 requires cryptography<44,>=41.0.5, but you have cryptography 44.0.0 which is incompatible.
# mcp 1.25.0 requires pydantic<3.0.0,>=2.11.0, but you have pydantic 2.10.4 which is incompatible.
# tensorflow 2.19.0 requires tensorboard~=2.19.0, but you have tensorboard 2.18.0 which is incompatible.
# diffusers 0.36.0 requires huggingface-hub<2.0,>=0.34.0, but you have huggingface-hub 0.27.0 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 44.0.0 which is incompatible.
# gradio 5.50.0 requires huggingface-hub<2.0,>=0.33.5, but you have huggingface-hub 0.27.0 which is incompatible.
# google-adk 1.21.0 requires authlib<2.0.0,>=1.5.1, but you have authlib 1.4.0 which is incompatible.
# google-adk 1.21.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# google-adk 1.21.0 requires starlette<1.0.0,>=0.49.1, but you have starlette 0.41.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.
# sse-starlette 3.1.2 requires starlette>=0.49.1, but you have starlette 0.41.3 which is incompatible.
# Successfully installed Pillow-11.0.0 accelerate-1.2.1 albucore-0.0.21 albumentations-1.4.23 authlib-1.4.0 autotrain-advanced-0.8.36 backports-zstd-1.3.0 bitsandbytes-0.45.0 colorlog-6.10.1 cryptography-44.0.0 datasets-3.2.0 einops-0.8.0 eval-type-backport-0.3.1 evaluate-0.4.3 fastapi-0.115.6 fsspec-2024.9.0 huggingface-hub-0.27.0 inflate64-1.0.4 ipadic-1.0.0 jiwer-3.0.5 joblib-1.4.2 lightning-utilities-0.15.2 loguru-0.7.3 multivolumefile-0.2.3 nvidia-ml-py-12.535.161 nvitop-1.3.2 optuna-4.1.0 packaging-24.2 pandas-2.2.3 peft-0.14.0 py7zr-0.22.0 pybcj-1.0.7 pycocotools-2.0.8 pydantic-2.10.4 pydantic-core-2.27.2 pyngrok-7.2.1 pyppmd-1.1.1 python-multipart-0.0.20 pyyaml-6.0.2 pyzstd-0.19.1 rapidfuzz-3.14.3 requests-2.32.3 rouge-score-0.1.2 sacremoses-0.1.1 scikit-learn-1.6.0 sentence-transformers-3.3.1 sentencepiece-0.2.0 seqeval-1.2.2 starlette-0.41.3 tensorboard-2.18.0 texttable-1.7.0 tiktoken-0.8.0 timm-1.0.12 tokenizers-0.21.4 torchmetrics-1.6.0 transformers-4.48.0 trl-0.13.0 uvicorn-0.34.0 werkzeug-3.1.3 xgboost-2.1.3

# %%
from autotrain.params import LLMTrainingParams
from autotrain.project import AutoTrainProject

# %%
HF_USERNAME = "ShahdAli333"
HF_TOKEN = "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" # get it from https://huggingface.co/settings/token
# It is recommended to use secrets or environment variables to store your HF_TOKEN
# your token is required if push_to_hub is set to True or if you are accessing a gated model/dataset

# %%
params = LLMTrainingParams(
    model="meta-llama/Llama-3.2-1B-Instruct",
    data_path="Dataset/Dataset_model",
    chat_template="tokenizer", # using the chat template defined in the model's tokenizer
    text_column="messages", # the column in the dataset that contains the text
    train_split="train"
    valid_split="validation",
    trainer="sft", # using the SFT trainer, choose from sft, default, orpo, dpo and reward
    epochs=3,
    batch_size=1,
    lr=1e-5,
    peft=True, # training LoRA using PEFT
    quantization="int4", # using int4 quantization
    target_modules="all-linear",
    padding="right",
    optimizer="paged_adamw_8bit",
    scheduler="cosine",
    gradient_accumulation=8,
    mixed_precision="bf16",
    merge_adapter=True,
    project_name="autotrain-llama32-1b-finetune",
    log="tensorboard",
    push_to_hub=True,
    username=HF_USERNAME,
    token=HF_TOKEN,
)

# %%
# this will train the model locally
project = AutoTrainProject(params=params, backend="local", process=True)
project.create()
# Out:
# INFO     | 2026-01-17 16:46:44 | autotrain.backends.local:create:20 - Starting local training...
# INFO     | 2026-01-17 16:46:44 | autotrain.commands:launch_command:514 - ['accelerate', 'launch', '--num_machines', '1', '--num_processes', '1', '--mixed_precision', 'bf16', '-m', 'autotrain.trainers.clm', '--training_config', 'autotrain-llama32-1b-finetune/training_params.json', '--mixed_precision', 'bf16', '-m', 'autotrain.trainers.clm', '--training_config', 'autotrain-llama32-1b-finetune/training_params.json', '--mixed_precision', 'bf16', '-m', 'autotrain.trainers.clm', '--training_config', 'autotrain-llama32-1b-finetune/training_params.json']
# INFO     | 2026-01-17 16:46:44 | autotrain.commands:launch_command:515 - {'model': 'meta-llama/Llama-3.2-1B-Instruct', 'project_name': 'autotrain-llama32-1b-finetune', 'data_path': 'Dataset/Dataset_model', 'train_split': 'train', 'valid_split': 'validation', 'add_eos_token': True, 'block_size': -1, 'model_max_length': 2048, 'padding': 'right', 'trainer': 'sft', 'use_flash_attention_2': False, 'log': 'tensorboard', 'disable_gradient_checkpointing': False, 'logging_steps': -1, 'eval_strategy': 'epoch', 'save_total_limit': 1, 'auto_find_batch_size': False, 'mixed_precision': 'bf16', 'lr': 1e-05, 'epochs': 3, 'batch_size': 1, 'warmup_ratio': 0.1, 'gradient_accumulation': 8, 'optimizer': 'paged_adamw_8bit', 'scheduler': 'cosine', 'weight_decay': 0.0, 'max_grad_norm': 1.0, 'seed': 42, 'chat_template': 'tokenizer', 'quantization': 'int4', 'target_modules': 'all-linear', 'merge_adapter': True, 'peft': True, 'lora_r': 16, 'lora_alpha': 32, 'lora_dropout': 0.05, 'model_ref': None, 'dpo_beta': 0.1, 'max_prompt_length': 128, 'max_completion_length': None, 'prompt_text_column': None, 'text_column': 'messages', 'rejected_text_column': None, 'push_to_hub': True, 'username': 'ShahdAli333', 'token': '*****', 'unsloth': False, 'distributed_backend': None}
# 13076
